# %%
import matplotlib.pyplot as plt

# %%
import cv2
from utils import get_data,loadimg

# %%
input_image = get_data('samples/28_LR.png')
expected_output = plt.imread('samples/28_HR.png')
# plt.imshow(input_image.squeeze())

# %%
plt.imshow(expected_output)

# %%
from tensorflow import keras
import Functionalmodel as Fm
from SubpixelConv2D import SubpixelConv2D
import numpy as np
from PIL import Image

G = Fm.get_G((96, 96, 3))
models = [180,260,280,300]
# G = keras.models.load_model(f'results/gener_{model}_h5', custom_objects = {'SubpixelConv2D' : SubpixelConv2D},compile=False)

# %%
for model in models:
    G = keras.models.load_model(f'results/gener_{model}_h5', custom_objects = {'SubpixelConv2D' : SubpixelConv2D},compile=False)
    output_image = G.predict(input_image)
    output_image= Image.fromarray(np.uint8(output_image.squeeze()*255))
    output_image = np.asarray(output_image)

    f, ax= plt.subplots(1,3, figsize=(16, 6))
    ax[0].imshow(input_image.squeeze(), aspect='auto')
    ax[1].imshow(output_image, aspect='auto')
    ax[2].imshow(expected_output, aspect='auto')
    plt.show()
# Out:
# 1/1 [==============================] - 0s 168ms/step
# 2023-03-22 14:49:18.012971: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 1/1 [==============================] - 0s 114ms/step
# 2023-03-22 14:49:18.563992: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 1/1 [==============================] - 0s 120ms/step
# 2023-03-22 14:49:19.027889: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 1/1 [==============================] - 0s 120ms/step
# 2023-03-22 14:49:19.492286: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.

# %%
# output_image = G.predict(input_image)
#     output_image= Image.fromarray(np.uint8(output_image.squeeze()*255))
# output_image = np.asarray(output_image)

# %%
# Importing the modules
import cv2
import numpy as np
  
# Reading the image
# image = cv2.imread(output_image)
  
# Creating the kernel with numpy
kernel2 = np.ones((5, 5), np.float32)/25
  
# Applying the filter
img = cv2.filter2D(src=img, ddepth=-1, kernel=kernel2)
  
# showing the image
cv2.imshow('Original', output_image)
cv2.imshow('Kernel Blur', img)

# %%
plt.imshow(img)
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import cv2
import numpy as np
# Load the input image
image = img
# Create the sharpening kernel
kernel = np.array([[-1,-1,-1], [-1,9,-1], [-1,-1,-1]])
# Apply the sharpening kernel to the image using filter2D
sharpened = cv2.filter2D(image, -1, kernel)

plt.imshow(sharpened)
